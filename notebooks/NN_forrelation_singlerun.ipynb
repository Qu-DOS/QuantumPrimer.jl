# %% [markdown]
# #### Set data

# %%
import numpy as np
import pandas as pd

# Set the random seed for reproducibility
np.random.seed(0)

# Load data
# data = np.load('../data/forr_rand_fns_n4_change_basis.npz')
# data = np.load('../data/forr_rand_fns_n6_change_basis.npz')
data = np.load('../data/forr_rand_fns_n8_change_basis.npz')

N = data['forr_f'].shape[2]

# Create training and testing data
x_train = np.zeros(data['forr_f'].shape)
x_test = np.zeros(data['forr_f'].shape)
y_train = np.zeros(data['forr_f'].shape[0])
y_test = np.zeros(data['forr_f'].shape[0])
for i in range(0, 25):
    # Training data
    x_train[i, :, :] = data["forr_f"][i, :, :]
    y_train[i] = 1
    x_train[i+25, :, :] = data["rand_f"][i, :, :]
    y_train[i+25] = 0
    # Test data
    x_test[i, :, :] = data["forr_f"][i+25, :, :]
    y_test[i] = 1
    x_test[i+25, :, :] = data["rand_f"][i+25, :, :]
    y_test[i+25] = 0

###############################################################################

# # Create random binary vectors for training
# x_train = np.random.randint(0, 2, (1000, 2, 10))

# # Create random binary vectors for testing
# x_test = np.random.randint(0, 2, (100, 2, 10))

# # Create binary labels for training and testing
# # In this example, a pair is labeled 1 if the two vectors are equal, and 0 otherwise
# y_train = np.all(x_train[:, 0] == x_train[:, 1], axis=1)
# y_test = np.all(x_test[:, 0] == x_test[:, 1], axis=1)

# %% [markdown]
# #### Build the model

# %%
from keras.models import Model
from keras.layers import Input, Flatten, Dense, Dropout, Lambda, Conv2D, MaxPooling2D
from tensorflow import keras as tfk

def euclidean_distance(vects):
    """
    Calculates the Euclidean distance between two vectors.

    Args:
        vects: A tuple of two vectors (x, y).

    Returns:
        The Euclidean distance between the two vectors.
    """
    x, y = vects
    return tfk.backend.sqrt(tfk.backend.maximum(tfk.backend.sum(tfk.backend.square(x - y), axis=1, keepdims=True), tfk.backend.epsilon()))

def eucl_dist_output_shape(shapes):
    """
    Calculates the output shape of the Euclidean distance layer.

    Parameters:
    shapes (tuple): A tuple containing the shapes of the input tensors.

    Returns:
    tuple: A tuple representing the output shape of the Euclidean distance layer.
        The first dimension is the batch size, and the second dimension is 1.
    """
    shape1, shape2 = shapes
    return (shape1[0], 1)

def create_base_network(input_shape):
    """
    Creates a base network for a neural network model.

    Parameters:
    input_shape (tuple): The shape of the input data.

    Returns:
    keras.Model: The base network model.
    """
    input = Input(shape=input_shape)
    # x = Conv2D(32, (3, 3), activation='relu')(input)
    # x = MaxPooling2D(pool_size=(2, 2))(x)
    # x = Conv2D(64, (3, 3), activation='relu')(x)
    # x = MaxPooling2D(pool_size=(2, 2))(x)
    x = Flatten()(input)
    x = Dense(128, activation='relu')(x) # use activation='sigmoid' if gradient-based optimization gives problems
    # x = Dropout(0.1)(x)
    x = Dense(128, activation='relu')(x)
    # x = Dropout(0.1)(x)
    x = Dense(128, activation='relu')(x)
    return Model(input, x)

# Create the base network
base_network = create_base_network((N,))

# Create the left input and point to the base network
input_a = Input(shape=(N,))
vect_output_a = base_network(input_a)

# Create the right input and point to the base network
input_b = Input(shape=(N,))
vect_output_b = base_network(input_b)

# Measure the similarity of the two vector outputs
output = Lambda(euclidean_distance, output_shape=eucl_dist_output_shape)([vect_output_a, vect_output_b])

# Specify the inputs and output of the model
model = Model([input_a, input_b], output)

# Compile the model
# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

# Save the weights of the model for easier resetting
model.save_weights('model.weights.h5')
# Out:
# 2024-06-07 14:33:13.115407: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-07 14:33:18.455064: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# #### Run model

# %%
# Reshape the data to fit the network input (samples, vector)
x_train_1 = x_train[:, 0].reshape(-1, N)
x_train_2 = x_train[:, 1].reshape(-1, N)
x_test_1 = x_test[:, 0].reshape(-1, N)
x_test_2 = x_test[:, 1].reshape(-1, N)

# Train the model and store the history into results_raw
history = model.fit([x_train_1, x_train_2], y_train, batch_size=128, epochs=100, validation_data=([x_test_1, x_test_2], y_test))
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.5000 - loss: 3.9120 - val_accuracy: 0.5000 - val_loss: 4.2535
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.5000 - loss: 2.3818 - val_accuracy: 0.5000 - val_loss: 3.4553
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.5000 - loss: 1.4381 - val_accuracy: 0.5000 - val_loss: 2.8345
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.5000 - loss: 0.8662 - val_accuracy: 0.5000 - val_loss: 2.3577
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.5000 - loss: 0.5356 - val_accuracy: 0.5000 - val_loss: 1.9909
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.5000 - loss: 0.3534 - val_accuracy: 0.5000 - val_loss: 1.7024
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.5000 - loss: 0.2545 - val_accuracy: 0.5000 - val_loss: 1.4741
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.5000 - loss: 0.1984 - val_accuracy: 0.5000 - val_loss: 1.2914
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 0.6000 - loss: 0.1614 - val_accuracy: 0.5000 - val_loss: 1.1435
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step - accuracy: 0.8200 - loss: 0.1343 - val_accuracy: 0.5000 - val_loss: 1.0204
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9400 - loss: 0.1128 - val_accuracy: 0.5000 - val_loss: 0.9193
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9600 - loss: 0.0947 - val_accuracy: 0.5000 - val_loss: 0.8358
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.9800 - loss: 0.0794 - val_accuracy: 0.5000 - val_loss: 0.7661
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 1.0000 - loss: 0.0669 - val_accuracy: 0.5000 - val_loss: 0.7076
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 1.0000 - loss: 0.0560 - val_accuracy: 0.5200 - val_loss: 0.6585
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 1.0000 - loss: 0.0471 - val_accuracy: 0.5200 - val_loss: 0.6169
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 1.0000 - loss: 0.0399 - val_accuracy: 0.5200 - val_loss: 0.5810
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 1.0000 - loss: 0.0342 - val_accuracy: 0.5200 - val_loss: 0.5498
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 1.0000 - loss: 0.0297 - val_accuracy: 0.5400 - val_loss: 0.5225
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 1.0000 - loss: 0.0260 - val_accuracy: 0.5400 - val_loss: 0.4980
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 1.0000 - loss: 0.0229 - val_accuracy: 0.5400 - val_loss: 0.4761
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 1.0000 - loss: 0.0202 - val_accuracy: 0.5800 - val_loss: 0.4564
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 1.0000 - loss: 0.0179 - val_accuracy: 0.6000 - val_loss: 0.4387
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 1.0000 - loss: 0.0157 - val_accuracy: 0.6200 - val_loss: 0.4225
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 1.0000 - loss: 0.0138 - val_accuracy: 0.6200 - val_loss: 0.4078
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 1.0000 - loss: 0.0122 - val_accuracy: 0.6200 - val_loss: 0.3942
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 1.0000 - loss: 0.0108 - val_accuracy: 0.6400 - val_loss: 0.3818
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 1.0000 - loss: 0.0096 - val_accuracy: 0.6800 - val_loss: 0.3706
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.6800 - val_loss: 0.3606
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.6800 - val_loss: 0.3516
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.7000 - val_loss: 0.3435
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.7000 - val_loss: 0.3363
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.7000 - val_loss: 0.3299
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.7200 - val_loss: 0.3242
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.7600 - val_loss: 0.3192
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.8000 - val_loss: 0.3147
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.8000 - val_loss: 0.3106
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.8000 - val_loss: 0.3069
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.8000 - val_loss: 0.3036
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.8200 - val_loss: 0.3006
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.8200 - val_loss: 0.2978
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.8200 - val_loss: 0.2952
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.8200 - val_loss: 0.2927
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.8400 - val_loss: 0.2904
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.8400 - val_loss: 0.2882
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8400 - val_loss: 0.2862
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8600 - val_loss: 0.2843
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8600 - val_loss: 0.2825
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8600 - val_loss: 0.2809
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.8600 - val_loss: 0.2794
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 1.0000 - loss: 9.5033e-04 - val_accuracy: 0.8600 - val_loss: 0.2781
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 1.0000 - loss: 8.7168e-04 - val_accuracy: 0.8600 - val_loss: 0.2769
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 1.0000 - loss: 7.9830e-04 - val_accuracy: 0.8600 - val_loss: 0.2758
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 1.0000 - loss: 7.2883e-04 - val_accuracy: 0.8600 - val_loss: 0.2748
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 1.0000 - loss: 6.6296e-04 - val_accuracy: 0.8600 - val_loss: 0.2740
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 1.0000 - loss: 6.0089e-04 - val_accuracy: 0.8600 - val_loss: 0.2733
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - accuracy: 1.0000 - loss: 5.4305e-04 - val_accuracy: 0.8600 - val_loss: 0.2727
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 1.0000 - loss: 4.9018e-04 - val_accuracy: 0.8600 - val_loss: 0.2721
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 1.0000 - loss: 4.4267e-04 - val_accuracy: 0.8600 - val_loss: 0.2716
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 1.0000 - loss: 4.0093e-04 - val_accuracy: 0.8600 - val_loss: 0.2712
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 1.0000 - loss: 3.6484e-04 - val_accuracy: 0.8600 - val_loss: 0.2708
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: